# %%
# Import our dependencies
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
# Import our input dataset
GeneticDisorder_df = pd.read_csv(
    Path(r"Resources\genetic_disorder.csv")
)
GeneticDisorder_df.head()
# Out:
#    Patient Age Genes in mother's side Inherited from father Maternal gene  \
# 0         11.0                     No                    No           Yes
# 1          4.0                     No                   Yes           Yes
# 2          6.0                    Yes                    No           Yes
# 3         10.0                    Yes                   Yes           Yes
# 4          6.0                     No                   Yes           Yes
#
#   Paternal gene  Blood cell count (mcL)  Father's age  \
# 0            No                5.209058          44.0
# 1           Yes                4.752272          42.0
# 2            No                4.620420          20.0
# 3            No                4.751452          57.0
# 4           Yes                4.876896          48.0
#
#                       Institute Name    Status Respiratory Rate (breaths/min)  \
# 0           Lemuel Shattuck Hospital     Alive                      Tachypnea
# 1           Shriners Burns Institute     Alive                      Tachypnea
# 2                     Not applicable     Alive                      Tachypnea
# 3  Massachusetts Eye & Ear Infirmary  Deceased                 Normal (30-60)
# 4                        VA Hospital  Deceased                      Tachypnea
#
#    ... H/O radiation exposure (x-ray) H/O substance abuse  \
# 0  ...                             No                  No
# 1  ...                             No                  No
# 2  ...                            Yes                   -
# 3  ...                            Yes                  No
# 4  ...                             No                  No
#
#   Assisted conception IVF/ART History of anomalies in previous pregnancies  \
# 0                          No                                          Yes
# 1                         Yes                                          Yes
# 2                          No                                           No
# 3                         Yes                                          Yes
# 4                         Yes                                           No
#
#   No. of previous abortion Birth defects  \
# 0                      0.0      Multiple
# 1                      1.0      Multiple
# 2                      3.0      Multiple
# 3                      3.0      Singular
# 4                      1.0      Singular
#
#   White Blood cell count (thousand per microliter)  Blood test result  \
# 0                                         6.669552  slightly abnormal
# 1                                         6.397702           abnormal
# 2                                         3.000000  slightly abnormal
# 3                                         9.382407           abnormal
# 4                                         7.370477             normal
#
#   Symptom 2                              Genetic Disorder
# 0       1.0   Mitochondrial genetic inheritance disorders
# 1       0.0  Multifactorial genetic inheritance disorders
# 2       0.0   Mitochondrial genetic inheritance disorders
# 3       1.0   Mitochondrial genetic inheritance disorders
# 4       0.0              Single-gene inheritance diseases
#
# [5 rows x 28 columns]

# %%
# Remove MYOPIC target from features data
y = ['Genetic Disorder']
X = GeneticDisorder_df.drop(columns=['Genetic Disorder'])

# %%
#Scale the data
from sklearn.datasets import make_blobs

X, y = make_blobs(centers=2, random_state=1, cluster_std=3)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)

# %%
# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=2))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7380 - accuracy: 0.4800
# Epoch 2/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7256 - accuracy: 0.4800
# Epoch 3/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7141 - accuracy: 0.4800
# Epoch 4/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7031 - accuracy: 0.4933
# Epoch 5/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.4933
# Epoch 6/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6819 - accuracy: 0.4933
# Epoch 7/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6715 - accuracy: 0.4933
# Epoch 8/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6610 - accuracy: 0.5200
# Epoch 9/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6512 - accuracy: 0.6133
# Epoch 10/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6412 - accuracy: 0.9333
# Epoch 11/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6315 - accuracy: 0.9467
# Epoch 12/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6217 - accuracy: 0.9467
# Epoch 13/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6116 - accuracy: 0.9467
# Epoch 14/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6018 - accuracy: 0.9467
# Epoch 15/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5916 - accuracy: 0.9467
# Epoch 16/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5814 - accuracy: 0.9467
# Epoch 17/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5706 - accuracy: 0.9467
# Epoch 18/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5598 - accuracy: 0.9600
# Epoch 19/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5489 - accuracy: 0.9733
# Epoch 20/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5375 - accuracy: 0.9733
# Epoch 21/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5266 - accuracy: 0.9733
# Epoch 22/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5150 - accuracy: 0.9733
# Epoch 23/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5037 - accuracy: 0.9733
# Epoch 24/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4919 - accuracy: 0.9733
# Epoch 25/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4800 - accuracy: 0.9733
# Epoch 26/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4679 - accuracy: 0.9733
# Epoch 27/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4556 - accuracy: 0.9733
# Epoch 28/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.9733
# Epoch 29/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4307 - accuracy: 0.9733
# Epoch 30/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4182 - accuracy: 0.9733
# Epoch 31/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4059 - accuracy: 0.9733
# Epoch 32/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.9733
# Epoch 33/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.9733
# Epoch 34/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3697 - accuracy: 0.9733
# Epoch 35/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.9733
# Epoch 36/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3464 - accuracy: 0.9733
# Epoch 37/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.9733
# Epoch 38/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3237 - accuracy: 0.9733
# Epoch 39/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3125 - accuracy: 0.9733
# Epoch 40/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3009 - accuracy: 0.9733
# Epoch 41/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2888 - accuracy: 0.9733
# Epoch 42/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2769 - accuracy: 0.9733
# Epoch 43/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2649 - accuracy: 0.9733
# Epoch 44/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2533 - accuracy: 0.9733
# Epoch 45/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2426 - accuracy: 0.9733
# Epoch 46/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2322 - accuracy: 0.9733
# Epoch 47/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 0.9733
# Epoch 48/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2129 - accuracy: 0.9733
# Epoch 49/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2041 - accuracy: 0.9733
# Epoch 50/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1958 - accuracy: 0.9733
# Epoch 51/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1878 - accuracy: 0.9733
# Epoch 52/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1803 - accuracy: 0.9733
# Epoch 53/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1733 - accuracy: 0.9733
# Epoch 54/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1666 - accuracy: 0.9733
# Epoch 55/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1603 - accuracy: 0.9733
# Epoch 56/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1544 - accuracy: 0.9733
# Epoch 57/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1488 - accuracy: 0.9733
# Epoch 58/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1435 - accuracy: 0.9733
# Epoch 59/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1386 - accuracy: 0.9733
# Epoch 60/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1338 - accuracy: 0.9733
# Epoch 61/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1294 - accuracy: 0.9733
# Epoch 62/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1252 - accuracy: 0.9733
# Epoch 63/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1212 - accuracy: 0.9733
# Epoch 64/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1174 - accuracy: 0.9733
# Epoch 65/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1139 - accuracy: 0.9733
# Epoch 66/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1104 - accuracy: 0.9733
# Epoch 67/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1073 - accuracy: 0.9733
# Epoch 68/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1043 - accuracy: 0.9733
# Epoch 69/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1014 - accuracy: 0.9733
# Epoch 70/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0986 - accuracy: 0.9733
# Epoch 71/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0959 - accuracy: 0.9733
# Epoch 72/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0934 - accuracy: 0.9733
# Epoch 73/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0910 - accuracy: 0.9733
# Epoch 74/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0886 - accuracy: 0.9733
# Epoch 75/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0864 - accuracy: 0.9733
# Epoch 76/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0843 - accuracy: 0.9733
# Epoch 77/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0822 - accuracy: 0.9733
# Epoch 78/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9733
# Epoch 79/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0783 - accuracy: 0.9733
# Epoch 80/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0765 - accuracy: 0.9733
# Epoch 81/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0746 - accuracy: 0.9733
# Epoch 82/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0729 - accuracy: 0.9733
# Epoch 83/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0711 - accuracy: 0.9733
# Epoch 84/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9733
# Epoch 85/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 0.9733
# Epoch 86/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0664 - accuracy: 0.9733
# Epoch 87/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9867
# Epoch 88/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0635 - accuracy: 0.9867
# Epoch 89/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 0.9867
# Epoch 90/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0610 - accuracy: 1.0000
# Epoch 91/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0596 - accuracy: 1.0000
# Epoch 92/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0584 - accuracy: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0572 - accuracy: 1.0000
# Epoch 94/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0560 - accuracy: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 1.0000
# Epoch 96/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 1.0000
# Epoch 97/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0527 - accuracy: 1.0000
# Epoch 98/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0517 - accuracy: 1.0000
# Epoch 99/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0507 - accuracy: 1.0000
# Epoch 100/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 1.0000
# 1/1 - 0s - loss: 0.0372 - accuracy: 1.0000 - 96ms/epoch - 96ms/step
# Loss: 0.03721326217055321, Accuracy: 1.0

# %%
# Create a logistic regression model
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs', random_state=1)

# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
from sklearn.metrics import accuracy_score
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 1.000
